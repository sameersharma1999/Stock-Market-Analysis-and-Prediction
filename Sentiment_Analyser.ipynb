# %%
import pandas as pd 
import numpy as np

import yfinance as yf
from bs4 import BeautifulSoup
import requests

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

import datetime

# %% [markdown]
# ## Largest Companies by Market Cap Today (TOP 49 LIST)

# %%
source = requests.get('https://www.dogsofthedow.com/largest-companies-by-market-cap.htm').text
soup = BeautifulSoup(source, 'lxml')

# %%
rows = [soup.find('tr', class_=f'row-{str(i)}') for i in range(2, 52)]

# %%
symbol = list()
company = list()
cap_rank = list()
market_cap = list()

for row in rows:
    sy = row.find('td', class_='column-1').a.text
    comp = row.find('td', class_='column-2').text
    cap_ran = row.find('td', class_='column-3').text
    mar_cap = row.find('td', class_='column-4').text
    
    if sy == 'BRK.A':
        continue
        
    symbol.append(sy)
    company.append(comp)
    cap_rank.append(cap_ran)
    market_cap.append(mar_cap)

# %%
top_49_companies = pd.DataFrame(data=list(zip(symbol, company, cap_rank, market_cap)), 
                                index=range(1, 50), 
                                columns=['Symbol', 'Company', 'Cap_Rank', 'Market_Cap'])

# %%
top_49_companies.head()
# Out:
#   Symbol    Company Cap_Rank Market_Cap
# 1   AAPL      Apple        1    2,035.4
# 2   MSFT  Microsoft        2    1,688.2
# 3   AMZN     Amazon        3    1,666.8
# 4  GOOGL   Alphabet        4    1,192.5
# 5     FB   Facebook        5      839.3

# %% [markdown]
# ## Get News of all Top 49 Companies

# %%
tickers = top_49_companies['Symbol']
finwiz_url = 'https://finviz.com/quote.ashx?t='
news_dict = dict()

numbers = [str(i) for i in range(0, 10)]

for ticker in tickers:
    
    dates = list()
    times = list()
    newss = list()
    
    url = finwiz_url + ticker
    source = requests.get(url=url, headers={'user-agent': 'my-app/0.0.1'}).text
    soup = BeautifulSoup(source, 'lxml')
    
    html = soup.find('table', id='news-table')
    rows = html.find_all('tr')
    
    today_date = datetime.date.today()
    
    for row in rows:
        date_time = row.td.text
        news = row.find('div', class_='news-link-left').a.text
        
        if date_time[0] not in numbers:
            datee = date_time.split(' ')[0]
            
            datee = datetime.datetime.strptime(datee, '%b-%d-20').date()
            datee = datetime.date(today_date.year,datee.month,datee.day)
            
            if datee != today_date:
                break
            time = date_time.split(' ')[1]
        else:
            time = date_time
            
        dates.append(datee)
        times.append(time.strip())
        newss.append(news)
            
    news_dict[ticker] = [dates, times, newss]

# %% [markdown]
# ## Sentiment Analysis

# %%
analyser = SentimentIntensityAnalyzer()

news = []
comp = []
compound = []

for company in news_dict:
    text = ''
    for i in news_dict[company][2]:
        text = text + ' ' + i
        
    d = analyser.polarity_scores(text)
    
    if d['compound'] > 0.05:
        compound.append('pos')
    elif d['compound'] > -0.05 and d['compound'] < 0.05:
        compound.append('neu')
    elif d['compound'] <= 0.05:
        compound.append('neg')
            
        
    news.append(text)
    comp.append(company)

# %%
top_49_company_news = pd.DataFrame(data=list(zip(comp, news, compound)), 
                                   columns=['Symbol', 'News', 'Sentiment'], 
                                   index=range(1, 50))

# %%
top_49_company_news.head()
# Out:
#   Symbol                                               News Sentiment
# 1   AAPL                                                          neu
# 2   MSFT                                                          neu
# 3   AMZN   Amazon to invest $2.8 billion to build its se...       pos
# 4  GOOGL   Deutsche Bank Alumni Are Helping Son Remake J...       pos
# 5     FB   Facebook removes 'inauthentic' networks spann...       pos

# %% [markdown]
# ## Merge the data sets

# %%
merged_df = top_49_companies.merge(right=top_49_company_news,
                        how='inner',
                        on=None)

# %%
merged_df
# Out:
#    Symbol                   Company Cap_Rank Market_Cap  \
# 0    AAPL                     Apple        1    2,035.4
# 1    MSFT                 Microsoft        2    1,688.2
# 2    AMZN                    Amazon        3    1,666.8
# 3   GOOGL                  Alphabet        4    1,192.5
# 4      FB                  Facebook        5      839.3
# 5     TSM      Taiwan Semiconductor        7      469.0
# 6       V                      Visa        8      420.6
# 7    TSLA                     Tesla        9      408.2
# 8     WMT                   Walmart       10      406.6
# 9     JNJ         Johnson & Johnson       11      367.9
# 10     PG          Procter & Gamble       12      351.6
# 11   NVDA                    NVIDIA       13      349.5
# 12    UNH              UnitedHealth       14      336.3
# 13    JPM            JPMorgan Chase       15      318.1
# 14     MA                Mastercard       16      315.6
# 15     HD                Home Depot       17      307.7
# 16     VZ                   Verizon       18      240.6
# 17   PYPL                    PayPal       19      239.7
# 18   ADBE                     Adobe       20      238.2
# 19    CRM                Salesforce       21      236.8
# 20    DIS                    Disney       22      229.4
# 21   NFLX                   Netflix       23      227.0
# 22    BAC           Bank of America       24      212.9
# 23     KO                 Coca-Cola       25      212.5
# 24    TMO  Thermo Fisher Scientific       26      204.0
# 25    NKE                      Nike       27      203.6
# 26    MRK                     Merck       28      203.5
# 27  CMCSA                   Comcast       29      202.9
# 28    PFE                    Pfizer       30      202.2
# 29    ABT       Abbott Laboratories       31      201.0
# 30      T                      AT&T       32      196.0
# 31    NVS               Novartis AG       33      192.8
# 32     TM                    Toyota       34      191.6
# 33    PEP                     Pepsi       35      190.8
# 34   INTC                     Intel       36      187.2
# 35    DHR                   Danaher       37      170.7
# 36   ORCL                    Oracle       38      170.4
# 37   COST          Costco Wholesale       39      170.0
# 38   ASML                      ASML       40      166.6
# 39   ABBV                    AbbVie       41      165.3
# 40   QCOM                  Qualcomm       42      164.1
# 41    MCD                McDonald's       43      161.0
# 42   CSCO             Cisco Systems       44      157.8
# 43    ACN                 Accenture       45      154.2
# 44   AVGO                  Broadcom       46      154.1
# 45    NEE            Nextera Energy       47      146.4
# 46   TMUS               T-Mobile US       48      145.1
# 47    AZN               AstraZeneca       49      144.8
# 48    BMY      Bristol-Myers Squibb       50      143.7
#
#                                                  News Sentiment
# 0                                                           neu
# 1                                                           neu
# 2    Amazon to invest $2.8 billion to build its se...       pos
# 3    Deutsche Bank Alumni Are Helping Son Remake J...       pos
# 4    Facebook removes 'inauthentic' networks spann...       pos
# 5                                                           neu
# 6                                                           neu
# 7    Tesla unveils 'Tesla Tequila' for $250, produ...       neu
# 8    Facebook Racks Up India Wins With WhatsApp Pe...       pos
# 9                                                           neu
# 10                                                          neu
# 11                                                          neu
# 12   Tandem Diabetes Care Inc (TNDM) Q3 2020 Earni...       pos
# 13                                                          neu
# 14                                                          neu
# 15                                                          neu
# 16                                                          neu
# 17                                                          neu
# 18                                                          neu
# 19                                                          neu
# 20   More Trouble For Movie Theaters As Disney Pos...       neg
# 21                                                          neu
# 22                                                          neu
# 23                                                          neu
# 24                                                          neu
# 25   Luxury, Beauty Brands and a Black Diamond Shi...       pos
# 26                                                          neu
# 27                                                          neu
# 28   ICU Medical Inc (ICUI) Q3 2020 Earnings Call ...       neg
# 29                                                          neu
# 30                                                          neu
# 31   Novartis arthritis drug fails to help COVID-1...       neu
# 32   Toyota-backed startup Pony.ai raises $267 mil...       neu
# 33                                                          neu
# 34   Facebook Racks Up India Wins With WhatsApp Pe...       pos
# 35                                                          neu
# 36                                                          neu
# 37                                                          neu
# 38                                                          neu
# 39                                                          neu
# 40                                                          neu
# 41                                                          neu
# 42                                                          neu
# 43                                                          neu
# 44                                                          neu
# 45                                                          neu
# 46                                                          neu
# 47   How Does AstraZeneca's (LON:AZN) CEO Salary C...       neu
# 48   Bristol-Myers Squibb (BMY) Q3 2020 Earnings C...       neu
